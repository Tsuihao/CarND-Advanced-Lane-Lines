# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
image = cv2.imread('warped_example.jpg')

# %%
plt.imshow(image)

# %%
np.mgrid[0:9, 0:6].T.reshape(-1,2).shape
# Out:
# (54, 2)

# %%
np.mgrid[0:3]
# Out:
# array([0, 1, 2])
